# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q silence-tensorflow
import silence_tensorflow.auto
# Out:
#   Building wheel for silence-tensorflow (setup.py) ... done

# %%
# Add Folders to path, required to import them
import sys
#sys.path.append('../input/maskrcnn-tf-2-efficientnetv2-caching/Instance_Segmentation/efficientnetv2')
#sys.path.append('../input/maskrcnn-tf-2-efficientnetv2-caching/Instance_Segmentation/Mask_RCNN')
sys.path.append('/content/drive/MyDrive/Sartorius/Sartorius/Mask_RCNN')
sys.path.append('/content/drive/MyDrive/Sartorius/Sartorius/efficientnetv2')
sys.path.append('/content/drive/MyDrive/Sartorius/SatoriusDataset')

# %%
# Install LZ4 Compression/Decompression Library
# !pip install -q /content/drive/MyDrive/Sartorius/Sartorius/lz4-3.1.3-cp37-cp37m-manylinux1_x86_64.whl

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.15.0

# %%
import matplotlib.pyplot as plt
import mrcnn.utils as utils
import mrcnn.model as modellib
import numpy as np
import pandas as pd
import tensorflow as tf

import os
import sys
import json
import time
import skimage
import imageio
import glob
import imgaug
import multiprocessing

from PIL import Image, ImageDraw
from tqdm.notebook import tqdm
from sklearn.model_selection import KFold
from PIL import Image, ImageEnhance
from mrcnn.config import Config
from mrcnn import visualize

# ignore warnings to make outputs clearer
import warnings
warnings.filterwarnings('ignore')

print(f'Python Version: {sys.version}')
print(f'Tensorflow Version: {tf.__version__}')
print(f'Tensorflow Keras Version: {tf.keras.__version__}')
# Out:
# Python Version: 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# Tensorflow Version: 2.7.0
# Tensorflow Keras Version: 2.7.0

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
train = pd.read_csv('/content/drive/MyDrive/SatoriusDataset/train.csv')

# Unique Image IDs
id_unique = train['id'].unique()

# Original Image File Path
def get_file_path(image_id):
    return f'/content/drive/MyDrive/SatoriusDataset/train/{image_id}.png'

train['file_path'] = train['id'].apply(get_file_path)

# Unique Cell Names
CELL_NAMES = np.sort(train['cell_type'].unique())
print(f'CELL_NAMES: {CELL_NAMES}')

# Cell Type to Label Dictionary
CELL_NAMES_DICT = dict([(v, k) for k, v in enumerate(CELL_NAMES)])
print(f'CELL_NAMES_DICT: {CELL_NAMES_DICT}')

# Add Cell Type Label to train, " + 1" becaue label 0 is reserved for background
train['cell_type_label'] = train['cell_type'].apply(CELL_NAMES_DICT.get) + 1

# Image Id to Cell Type Label Dictionary
ID2CELL_LABEL = dict(
    [(k, v) for k, v in train[['id', 'cell_type_label']].itertuples(name=None, index=False)]
)
# Out:
# CELL_NAMES: ['astro' 'cort' 'shsy5y']
# CELL_NAMES_DICT: {'astro': 0, 'cort': 1, 'shsy5y': 2}

# %%
# path to COCO-dataset weights
COCO_MODEL_PATH = '/content/drive/MyDrive/Sartorius/Sartorius/mask_rcnn_coco.h5'

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %% [markdown]
# **Training Configuration**

# %%
# Original Image Dimensions
HEIGHT = 520
WIDTH = 704
SHAPE = (HEIGHT, WIDTH)

# Target Image Dimensions which are divisable by 64 as required by the MASK-RCNN model
HEIGHT_TARGET = 576
WIDTH_TARGET = 704
SHAPE_TARGET = (HEIGHT_TARGET, WIDTH_TARGET)

BATCH_SIZE = 1
N_SAMPLES = train['id'].nunique()

# Debug mode for fast experementing with 50 samples
DEBUG = False
DEBUG_SIZE = 50

# %%
EPOCHS_ALL = 10 if DEBUG else 20

# %% [markdown]
# **Model Configuration**

# %% [markdown]
# 1.   Class classification size is reduced from 1024 to 128 to reduce model size, which is done to reduce overfitting. The COCO dataset contains 80 object classes, whereas this training method only contains a single "cell" class, requiring less parameters.
# 2.   Disable multithreading for data generators by setting workers to 0. Surprisingly, multithreading is slower than running the data generator on a single core.

# %%
class CellConfig(Config):
    """Configuration for training on the cigarette butts dataset.
    Derives from the base Config class and overrides values specific
    to the cigarette butts dataset.
    """
    
    NAME = "cell"

    # Set batch size to 1.
    GPU_COUNT = 1
    IMAGES_PER_GPU = BATCH_SIZE
    STEPS_PER_EPOCH = int(DEBUG_SIZE / BATCH_SIZE)  if DEBUG else int(N_SAMPLES / BATCH_SIZE)
    
    # Number of Classes
    NUM_CLASSES = 1 + len(CELL_NAMES)

    # Image Dimensions
    IMAGE_MIN_DIM = HEIGHT_TARGET
    IMAGE_MAX_DIM = WIDTH_TARGET
    IMAGE_SHAPE = [HEIGHT_TARGET, WIDTH_TARGET, 3]
    IMAGE_RESIZE_MODE = 'none'
    
    BACKBONE = 'efficientnetv2-b0'

    # Training Structure
    FPN_CLASSIF_FC_LAYERS_SIZE = 1024
    RPN_ANCHOR_SCALES = (32, 64, 128, 256, 512)
    # Regions of Interest
    PRE_NMS_LIMIT = 6000
    # Non Max Supression
    POST_NMS_ROIS_TRAINING = 2000
    POST_NMS_ROIS_INFERENCE = 2000
    # Instances
    MAX_GT_INSTANCES = 790
    TRAIN_ROIS_PER_IMAGE = 200
    DETECTION_MAX_INSTANCES = 200
    
    # Thresholds
    RPN_NMS_THRESHOLD = 0.70        # IoU Threshold for RPN proposals and GT
    DETECTION_MIN_CONFIDENCE = 0.50 # Non-Background Confidence Threshold
    DETECTION_NMS_THRESHOLD = 0.30  # IoU Threshold for ROI and GT
    ROI_POSITIVE_RATIO = 0.33
    
    # Prediction Mask Shape
    MASK_SHAPE = (56, 56)
    # Size of mask groundtruth
    USE_MINI_MASK = True
    MINI_MASK_SHAPE = (112, 112)
    
    # DO NOT train Batch Normalization because of small batch size
    # There are too few samples to correctly train the normalization
    TRAIN_BN = False
    
    # Learning Rate
    LEARNING_RATE = 0.004
    WEIGHT_DECAY = 0.0
    N_WARMUP_STEPS = 2
    LR_SCHEDULE = True
    
    # Dataloader Queue Size (was set to 100 but resulted in OOM error)
    MAX_QUEUE_SIZE = 10
    
    # Cache Items
    CACHE = True
    
    # Debug mode will disable model checkpoints
    DEBUG = False
    
    # Do not use multithreading as this slows down the dataloader!
    WORKERS = 0
    
    # Losses
    LOSS_WEIGHTS = {
        'rpn_class_loss': 1.0,    # is the class of the bbox correct? / RPN anchor classifier loss (Forground/Background)
        'rpn_bbox_loss': 1.0,     # is the size of the bbox correct? / RPN bounding box loss graph (bbox of generic object)
        'mrcnn_class_loss': 1.0,  # loss for the classifier head of Mask R-CNN (Background / specific class)
        'mrcnn_bbox_loss': 1.0,   # is the size of the bounding box correct or not? / loss for Mask R-CNN bounding box refinement
        'mrcnn_mask_loss': 1.0,   # is the class correct? is the pixel correctly assign to the class? / mask binary cross-entropy loss for the masks head
    }
    
config = CellConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       efficientnetv2-b0
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# CACHE                          True
# COMPUTE_BACKBONE_SHAPE         None
# DEBUG                          False
# DETECTION_MAX_INSTANCES        200
# DETECTION_MIN_CONFIDENCE       0.5
# DETECTION_NMS_THRESHOLD        0.3
# EFNV2_WEIGHTS                  None
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  704
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  576
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              none
# IMAGE_SHAPE                    [576 704   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.004
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# LR_SCHEDULE                    True
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     (56, 56)
# MAX_GT_INSTANCES               790
# MAX_QUEUE_SIZE                 10
# MEAN_PIXEL                     [0.519 0.519 0.519]
# MINI_MASK_SHAPE                (112, 112)
# NAME                           cell
# NUM_CLASSES                    4
# N_WARMUP_STEPS                 2
# PIXEL_CONFIDENCE_MASKS         False
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        2000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STD_PIXEL                      [0.296 0.296 0.296]
# STEPS_PER_EPOCH                606
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0
# WORKERS                        0

# %% [markdown]
# **RLE Decode**

# %%
# ref: https://www.kaggle.com/paulorzp/run-length-encode-and-decode
def rle_decode_by_image_id(image_id):
    rows = train.loc[train['id'] == image_id]
    
    # Image Shape
    mask = np.full(shape=[len(rows), np.prod(SHAPE)], fill_value=0, dtype=np.uint8)
    
    for idx, (_, row) in enumerate(rows.iterrows()):
        s = row['annotation'].split()
        starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
        starts -= 1
        ends = starts + lengths
        for lo, hi in zip(starts, ends):
            mask[idx, lo:hi] = True
    
    mask = mask.reshape([len(rows), *SHAPE])
    mask = np.moveaxis(mask, 0, 2)
    
    return mask

# %% [markdown]
# **Create Training Dataset**

# %%
# Function to pad images and masks
def pad_image(image, constant_values):
    pad_h = (HEIGHT_TARGET - HEIGHT) // 2
    pad_w = (WIDTH_TARGET - WIDTH) // 2
    
    if len(image.shape) == 3:
        return np.pad(image, ((pad_h, pad_h), (pad_w, pad_w), (0,0)), constant_values=constant_values)
    else:
        return np.pad(image, ((pad_h, pad_h), (pad_w, pad_w)), constant_values=constant_values)

# %%
# !rm -rf ./train ./test
# !mkdir ./train ./test

# %%
id_unique = train['id'].unique()
if DEBUG:
    id_unique = id_unique[:DEBUG_SIZE]

image_id2file_path = train.groupby('id')[['id', 'file_path']].head(1)
image_id2file_path = image_id2file_path.set_index('id').squeeze().to_dict()

# Create padded training samples with enhanced contrast
for image_id in tqdm(id_unique):
    # Read Original Image
    image = imageio.imread(image_id2file_path[image_id])
    # Pad Image
    image = pad_image(image, 128)
    
    # Save image in working directory, required for Mask-RCNN
    imageio.imwrite(f'./train/{image_id}.png', image)
# Out:
#   0%|          | 0/606 [00:00<?, ?it/s]

# %% [markdown]
# **Dataset**

# %%
class CellDataset(utils.Dataset):

    def load_data(self, image_ids, form, image_group):
   
        for i, name in enumerate(CELL_NAMES):
            self.add_class('cell', 1 + i, name)
       
        # Add the image using the base method from utils.Dataset
        for vertical_flip in [True, False]:
            for horizontal_flip in [True, False]:
                for image in tqdm(image_ids):
                    self.add_image('cell', 
                           image_id=image, 
                           path=(f'./{image_group}/{image}.png'), 
                           label = ID2CELL_LABEL[image],
                           height=512, width=512,
                          vertical_flip=vertical_flip, horizontal_flip=horizontal_flip,
                      )
            
            
    def load_mask(self, image_id):
        """ Load instance masks for the given image.
        MaskRCNN expects masks in the form of a bitmap [height, width, instances].
        Args:
            image_id: The id of the image to load masks for
        Returns:
            masks: A bool array of shape [height, width, instance count] with
                one mask per instance.
            class_ids: a 1D array of class IDs of the instance masks.
        """
    
        info = self.image_info[image_id]
        image_id = info['id']
    
        # Get masks by image_id
        masks = rle_decode_by_image_id(image_id)
        masks = pad_image(masks, 0)

        # Get label
        _, _, size = masks.shape
        label = info['label']
        class_ids = np.full(size, label, dtype=np.int32)
        
        return masks, class_ids

# %%
# Create Training Dataset
dataset_train = CellDataset()
dataset_train.load_data(id_unique, 'png', 'train')
dataset_train.prepare()
# Out:
#   0%|          | 0/606 [00:00<?, ?it/s]
#   0%|          | 0/606 [00:00<?, ?it/s]
#   0%|          | 0/606 [00:00<?, ?it/s]
#   0%|          | 0/606 [00:00<?, ?it/s]

# %%
# Plot Training Samples with Target Masks, note the instance classes!
dataset = dataset_train
image_ids = np.random.choice(dataset.image_ids, 5)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %% [markdown]
# **Model**

# %%
# Create model in training mode
# !mkdir 'model_checkpoints'
model = modellib.MaskRCNN(mode="training", config=config, model_dir='model_checkpoints')
# Out:
# Using EfficientNetV2 Model efficientnetv2-b0
# embedding shape: (None, 1280), C1 shape: (None, 288, 352, 16), C2 shape: (None, 144, 176, 32), C3 shape: (None, 72, 88, 48), C4 shape: (None, 36, 44, 112), C5 shape: (None, 18, 22, 192)

# %%
init_with = "coco"
exclude = ["mrcnn_class_logits", "mrcnn_bbox_fc", "mrcnn_bbox", "mrcnn_mask"]
if 'efficientnetv2-b' in config.BACKBONE:
    exclude += [
        "fpn_c5p5", "fpn_c4p4", "fpn_c3p3", "fpn_c2p2",
    ]
    
# Excluce FC layer if it is not the original size
if config.FPN_CLASSIF_FC_LAYERS_SIZE != 1024:
    print(f'Excluding FC layer')
    exclude += [
        "mrcnn_class_conv1", "mrcnn_class_bn1", "mrcnn_class_conv2", "mrcnn_class_bn2",
    ]
    
# using coco weights
model.load_weights(
    COCO_MODEL_PATH,
    by_name=True,
    exclude=exclude,
)

# %%
# Load EfficientNetV2 Weights Pretrained on Imagenet21K 
model.keras_model.layers[1].load_weights('/content/drive/MyDrive/Sartorius/Sartorius/efficientnetv2_model_checkpoints/efficientnetv2-b0-imagenet21k.h5')

# %%
model.show_summary()
# Out:
# Model: "mask_rcnn"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_image (InputLayer)                        [(None, 576, 704, 3)]            0                 []
#
#  efficientnetv2-b0 (EffNetV2Model)               multiple                         5919312           ['input_image[0][0]']
#
#  fpn_c5p5 (Conv2D)                               (None, 18, 22, 256)              49408             ['efficientnetv2-b0[1][5]']
#
#  fpn_p5upsampled (UpSampling2D)                  (None, 36, 44, 256)              0                 ['fpn_c5p5[0][0]']
#
#  fpn_c4p4 (Conv2D)                               (None, 36, 44, 256)              28928             ['efficientnetv2-b0[1][4]']
#
#  fpn_p4add (Add)                                 (None, 36, 44, 256)              0                 ['fpn_p5upsampled[0][0]',
#                                                                                                      'fpn_c4p4[0][0]']
#
#  fpn_p4upsampled (UpSampling2D)                  (None, 72, 88, 256)              0                 ['fpn_p4add[0][0]']
#
#  fpn_c3p3 (Conv2D)                               (None, 72, 88, 256)              12544             ['efficientnetv2-b0[1][3]']
#
#  fpn_p3add (Add)                                 (None, 72, 88, 256)              0                 ['fpn_p4upsampled[0][0]',
#                                                                                                      'fpn_c3p3[0][0]']
#
#  fpn_p3upsampled (UpSampling2D)                  (None, 144, 176, 256)            0                 ['fpn_p3add[0][0]']
#
#  fpn_c2p2 (Conv2D)                               (None, 144, 176, 256)            8448              ['efficientnetv2-b0[1][2]']
#
#  fpn_p2add (Add)                                 (None, 144, 176, 256)            0                 ['fpn_p3upsampled[0][0]',
#                                                                                                      'fpn_c2p2[0][0]']
#
#  fpn_p5 (Conv2D)                                 (None, 18, 22, 256)              590080            ['fpn_c5p5[0][0]']
#
#  fpn_p2 (Conv2D)                                 (None, 144, 176, 256)            590080            ['fpn_p2add[0][0]']
#
#  fpn_p3 (Conv2D)                                 (None, 72, 88, 256)              590080            ['fpn_p3add[0][0]']
#
#  fpn_p4 (Conv2D)                                 (None, 36, 44, 256)              590080            ['fpn_p4add[0][0]']
#
#  fpn_p6 (MaxPooling2D)                           (None, 9, 11, 256)               0                 ['fpn_p5[0][0]']
#
#  rpn_model (Functional)                          [(None, None, 2),                1189394           ['fpn_p2[0][0]',
#                                                   (None, None, 2),                                   'fpn_p3[0][0]',
#                                                   (None, None, 4)]                                   'fpn_p4[0][0]',
#                                                                                                      'fpn_p5[0][0]',
#                                                                                                      'fpn_p6[0][0]']
#
#  rpn_class (Concatenate)                         (None, None, 2)                  0                 ['rpn_model[0][1]',
#                                                                                                      'rpn_model[1][1]',
#                                                                                                      'rpn_model[2][1]',
#                                                                                                      'rpn_model[3][1]',
#                                                                                                      'rpn_model[4][1]']
#
#  rpn_bbox (Concatenate)                          (None, None, 4)                  0                 ['rpn_model[0][2]',
#                                                                                                      'rpn_model[1][2]',
#                                                                                                      'rpn_model[2][2]',
#                                                                                                      'rpn_model[3][2]',
#                                                                                                      'rpn_model[4][2]']
#
#  anchors (ConstLayer)                            (1, 101277, 4)                   405108            ['input_image[0][0]']
#
#  input_gt_boxes (InputLayer)                     [(None, None, 4)]                0                 []
#
#  ROI (ProposalLayer)                             (1, 2000, 4)                     0                 ['rpn_class[0][0]',
#                                                                                                      'rpn_bbox[0][0]',
#                                                                                                      'anchors[0][0]']
#
#  input_gt_class_ids (InputLayer)                 [(None, None)]                   0                 []
#
#  lambda (Lambda)                                 (None, None, 4)                  0                 ['input_gt_boxes[0][0]']
#
#  input_gt_masks (InputLayer)                     [(None, 112, 112, None)]         0                 []
#
#  proposal_targets (DetectionTargetLayer)         [(1, None, 4),                   0                 ['ROI[0][0]',
#                                                   (1, None),                                         'input_gt_class_ids[0][0]',
#                                                   (1, None, 4),                                      'lambda[0][0]',
#                                                   (1, None, 56, 56)]                                 'input_gt_masks[0][0]']
#
#  input_image_meta (InputLayer)                   [(None, 16)]                     0                 []
#
#  roi_align_mask (PyramidROIAlign)                (1, None, 14, 14, 256)           0                 ['proposal_targets[0][0]',
#                                                                                                      'input_image_meta[0][0]',
#                                                                                                      'fpn_p2[0][0]',
#                                                                                                      'fpn_p3[0][0]',
#                                                                                                      'fpn_p4[0][0]',
#                                                                                                      'fpn_p5[0][0]']
#
#  mrcnn_mask_conv1 (TimeDistributed)              (1, None, 14, 14, 256)           590080            ['roi_align_mask[0][0]']
#
#  mrcnn_mask_bn1 (TimeDistributed)                (1, None, 14, 14, 256)           1024              ['mrcnn_mask_conv1[0][0]']
#
#  activation_3 (Activation)                       (1, None, 14, 14, 256)           0                 ['mrcnn_mask_bn1[0][0]']
#
#  mrcnn_mask_conv2 (TimeDistributed)              (1, None, 14, 14, 256)           590080            ['activation_3[0][0]']
#
#  mrcnn_mask_bn2 (TimeDistributed)                (1, None, 14, 14, 256)           1024              ['mrcnn_mask_conv2[0][0]']
#
#  activation_4 (Activation)                       (1, None, 14, 14, 256)           0                 ['mrcnn_mask_bn2[0][0]']
#
#  mrcnn_mask_conv3 (TimeDistributed)              (1, None, 14, 14, 256)           590080            ['activation_4[0][0]']
#
#  mrcnn_mask_bn3 (TimeDistributed)                (1, None, 14, 14, 256)           1024              ['mrcnn_mask_conv3[0][0]']
#
#  roi_align_classifier (PyramidROIAlign)          (1, None, 7, 7, 256)             0                 ['proposal_targets[0][0]',
#                                                                                                      'input_image_meta[0][0]',
#                                                                                                      'fpn_p2[0][0]',
#                                                                                                      'fpn_p3[0][0]',
#                                                                                                      'fpn_p4[0][0]',
#                                                                                                      'fpn_p5[0][0]']
#
#  activation_5 (Activation)                       (1, None, 14, 14, 256)           0                 ['mrcnn_mask_bn3[0][0]']
#
#  mrcnn_class_conv1 (TimeDistributed)             (1, None, 1, 1, 1024)            12846080          ['roi_align_classifier[0][0]']
#
#  mrcnn_mask_conv4 (TimeDistributed)              (1, None, 14, 14, 256)           590080            ['activation_5[0][0]']
#
#  mrcnn_class_bn1 (TimeDistributed)               (1, None, 1, 1, 1024)            4096              ['mrcnn_class_conv1[0][0]']
#
#  mrcnn_mask_bn4 (TimeDistributed)                (1, None, 14, 14, 256)           1024              ['mrcnn_mask_conv4[0][0]']
#
#  activation (Activation)                         (1, None, 1, 1, 1024)            0                 ['mrcnn_class_bn1[0][0]']
#
#  activation_6 (Activation)                       (1, None, 14, 14, 256)           0                 ['mrcnn_mask_bn4[0][0]']
#
#  mrcnn_class_conv2 (TimeDistributed)             (1, None, 1, 1, 1024)            1049600           ['activation[0][0]']
#
#  mrcnn_mask_deconv (TimeDistributed)             (1, None, 28, 28, 256)           262400            ['activation_6[0][0]']
#
#  mrcnn_class_bn2 (TimeDistributed)               (1, None, 1, 1, 1024)            4096              ['mrcnn_class_conv2[0][0]']
#
#  mrcnn_mask_conv5 (TimeDistributed)              (1, None, 28, 28, 256)           590080            ['mrcnn_mask_deconv[0][0]']
#
#  activation_1 (Activation)                       (1, None, 1, 1, 1024)            0                 ['mrcnn_class_bn2[0][0]']
#
#  mrcnn_mask_bn5 (TimeDistributed)                (1, None, 28, 28, 256)           1024              ['mrcnn_mask_conv5[0][0]']
#
#  pool_squeeze (Lambda)                           (1, None, 1024)                  0                 ['activation_1[0][0]']
#
#  activation_7 (Activation)                       (1, None, 28, 28, 256)           0                 ['mrcnn_mask_bn5[0][0]']
#
#  mrcnn_bbox_fc (TimeDistributed)                 (1, None, 16)                    16400             ['pool_squeeze[0][0]']
#
#  mrcnn_mask_deconv2 (TimeDistributed)            (1, None, 56, 56, 256)           262400            ['activation_7[0][0]']
#
#  rpn_class_logits (Concatenate)                  (None, None, 2)                  0                 ['rpn_model[0][0]',
#                                                                                                      'rpn_model[1][0]',
#                                                                                                      'rpn_model[2][0]',
#                                                                                                      'rpn_model[3][0]',
#                                                                                                      'rpn_model[4][0]']
#
#  mrcnn_class_logits (TimeDistributed)            (1, None, 4)                     4100              ['pool_squeeze[0][0]']
#
#  mrcnn_bbox (Reshape)                            (1, None, 4, 4)                  0                 ['mrcnn_bbox_fc[0][0]']
#
#  mrcnn_mask (TimeDistributed)                    (1, None, 56, 56, 4)             1028              ['mrcnn_mask_deconv2[0][0]']
#
#  input_rpn_match (InputLayer)                    [(None, None, 1)]                0                 []
#
#  input_rpn_bbox (InputLayer)                     [(None, None, 4)]                0                 []
#
#  lambda_3 (Lambda)                               (None, 4)                        0                 ['input_image_meta[0][0]']
#
#  mrcnn_class (TimeDistributed)                   (1, None, 4)                     0                 ['mrcnn_class_logits[0][0]']
#
#  output_rois (Lambda)                            (1, None, 4)                     0                 ['proposal_targets[0][0]']
#
#  rpn_class_loss (Lambda)                         ()                               0                 ['input_rpn_match[0][0]',
#                                                                                                      'rpn_class_logits[0][0]']
#
#  rpn_bbox_loss (Lambda)                          ()                               0                 ['input_rpn_bbox[0][0]',
#                                                                                                      'input_rpn_match[0][0]',
#                                                                                                      'rpn_bbox[0][0]']
#
#  mrcnn_class_loss (Lambda)                       ()                               0                 ['proposal_targets[0][1]',
#                                                                                                      'mrcnn_class_logits[0][0]',
#                                                                                                      'lambda_3[0][0]']
#
#  mrcnn_bbox_loss (Lambda)                        ()                               0                 ['proposal_targets[0][2]',
#                                                                                                      'proposal_targets[0][1]',
#                                                                                                      'mrcnn_bbox[0][0]']
#
#  mrcnn_mask_loss (Lambda)                        ()                               0                 ['proposal_targets[0][3]',
#                                                                                                      'proposal_targets[0][1]',
#                                                                                                      'mrcnn_mask[0][0]']
#
# ======================================================================================================================================================
# Total params: 27,379,182
# Trainable params: 27,311,918
# Non-trainable params: 67,264
# ______________________________________________________________________________________________________________________________________________________
# None

# %%
# Show Mask-RCNN Architecture
plt.figure(figsize=(25, 10))
plt.title('Mask-RCNN Model Architecture')
plt.imshow(imageio.imread('./model.png'))
plt.axis(False)
plt.show()

# %%
# Added functionality, show learning rate schedule
model.plot_lr_schedule(EPOCHS_ALL)

# %% [markdown]
# **Training Whole Model**

# %% [markdown]
# here the actual training happens. Training will be increasingly fast as the training samples are cached and cache hits increase.

# %%
start_train = time.time()
history = model.train(
    dataset_train, None, 
    learning_rate=config.LEARNING_RATE,
    epochs=EPOCHS_ALL, 
    layers="all",
    augmentation=None,
)

end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')
# Out:
# LR_SCHEDULE: 1.0E-03, 2.0E-03, 4.0E-03, 4.0E-03, 3.9E-03, 3.7E-03, 3.5E-03, 3.3E-03, 3.0E-03, 2.7E-03, 2.3E-03, 2.0E-03, 1.7E-03, 1.3E-03, 1.0E-03, 7.1E-04, 4.7E-04, 2.7E-04, 1.2E-04, 3.0E-05
#
# Starting at epoch 0. LR=0.004
#
# Checkpoint Path: model_checkpoints/cell20220210T1125/mask_rcnn_cell_{epoch:04d}.h5
# Selecting layers to train
#     blocks_0               (FusedMBConvBlock)
#     blocks_1               (FusedMBConvBlock)
#     blocks_2               (FusedMBConvBlock)
#     blocks_3               (FusedMBConvBlock)
#     blocks_4               (FusedMBConvBlock)
#     blocks_5               (MBConvBlock)
#     blocks_6               (MBConvBlock)
#     blocks_7               (MBConvBlock)
#     blocks_8               (MBConvBlock)
#     blocks_9               (MBConvBlock)
#     blocks_10              (MBConvBlock)
#     blocks_11              (MBConvBlock)
#     blocks_12              (MBConvBlock)
#     blocks_13              (MBConvBlock)
#     blocks_14              (MBConvBlock)
#     blocks_15              (MBConvBlock)
#     blocks_16              (MBConvBlock)
#     blocks_17              (MBConvBlock)
#     blocks_18              (MBConvBlock)
#     blocks_19              (MBConvBlock)
#     blocks_20              (MBConvBlock)
#     stem                   (Stem)
# Found head layer in EfficientNetV2 to set untrainable | head
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# anchors                (ConstLayer)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv5       (TimeDistributed)
# mrcnn_mask_bn5         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv2     (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Not Applying Weights Decay
# Using 0 workers for data generators
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/20
# 369/606 [=================>............] - ETA: 3:12:17 - batch: 184.0000 - size: 1.0000 - loss: 3.8374 - rpn_class_loss: 0.4979 - rpn_bbox_loss: 1.3912 - mrcnn_class_loss: 0.5879 - mrcnn_bbox_loss: 0.7031 - mrcnn_mask_loss: 0.6573

# %%
def plot_history_metric(metric, f_best=np.argmax):
    values = history.history[metric]
    plt.figure(figsize=(15, 8))
    N_EPOCHS = len(values)
    # Epoch Ticks
    if N_EPOCHS <= 20:
        x = np.arange(1, N_EPOCHS + 1)
    else:
        x = [1, 5] + [10 + 5 * idx for idx in range((N_EPOCHS - 10) // 5 + 1)]
    x_ticks = np.arange(1, N_EPOCHS+1)
        
    # summarize history for accuracy
    plt.plot(x_ticks, values, label='train')
    argmin = f_best(values)
    plt.scatter(argmin + 1, values[argmin], color='red', s=75, marker='o', label='train_best')
    
    plt.title(f'Model {metric}', fontsize=24, pad=10)
    plt.ylabel(metric, fontsize=20, labelpad=10)
    plt.xlabel('epoch', fontsize=20, labelpad=10)
    plt.tick_params(axis='x', labelsize=8)
    plt.xticks(x, fontsize=16) # set tick step to 1 and let x axis start at 1
    plt.yticks(fontsize=16)
    plt.legend(prop={'size': 18})
    plt.grid()

# %%
plot_history_metric('loss', f_best=np.argmin)

# %%
# Region Proposal Network Foreground / Background Classifier
plot_history_metric('rpn_class_loss', f_best=np.argmin)

# %%
# Region Proposal Network Bounding Box Loss
plot_history_metric('rpn_bbox_loss', f_best=np.argmin)

# %%
# Mask RCNN Head Class Classifier Background / specific class
plot_history_metric('mrcnn_class_loss', f_best=np.argmin)

# %%
# # Mask RCNN Head Bounding Box Loss
plot_history_metric('mrcnn_bbox_loss', f_best=np.argmin)

# %%
# Mask RCNN Head Object Mask Binary Cross Entropy Loss
plot_history_metric('mrcnn_mask_loss', f_best=np.argmin)

# %%
class InferenceConfig(CellConfig):
    IMAGES_PER_GPU = 1
    DETECTION_MAX_INSTANCES = 200
    DETECTION_MIN_CONFIDENCE = 0.70
    USE_MINI_MASK = False
    

inference_config = InferenceConfig()
inference_config.display()

# %%
# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", config=inference_config, model_dir='model_checkpoints')

# %%
# Set EfficientNetV2 head untrainable
if 'efficientnetv2-b' in  inference_config.BACKBONE:
    model.keras_model.layers[1].layers[-1].trainable = False

# %%
# Find last epoch
model_path = model.find_last()

# Load trained weights (fill in path to trained weights here)
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)

# %%
for file_path in glob.glob('./train/*.png')[:25]:
    img = skimage.io.imread(file_path)
    img = np.expand_dims(img, axis=2)
    img = np.concatenate((img, img, img), axis=2)
    results = model.detect([img], verbose=1)
    r = results[0]
    
    # Image Id
    image_id = file_path.split('/')[-1].split('.')[0]
    print(f'image_id: {image_id}')
    
    mask = rle_decode_by_image_id(image_id)
    mask = np.sum(mask, axis=2)
    plt.figure(figsize=(16,16))
    plt.imshow(mask)
    plt.show()
    
    visualize.display_instances(
        img,
        r['rois'],
        r['masks'],
        r['class_ids'], 
        ['BG'] + CELL_NAMES.tolist(),
        r['scores'],
        figsize=(16,16)
    )
